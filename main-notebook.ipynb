# %%
import sqlite3
import pandas as pd
import requests
import time

# %%
# %load_ext autoreload
# %autoreload 2

# %%
url = "http://universities.hipolabs.com/search?country=Brazil"

# %%
response = requests.get(url)
response.raise_for_status()
universities = response.json()

# %%
universities[0]
# Out:
# {'name': 'Universidade Comunitária da Região de Chapecó - Unochapecó',
#  'web_pages': ['https://unochapeco.edu.br'],
#  'domains': ['unochapeco.edu.br'],
#  'country': 'Brazil',
#  'alpha_two_code': 'BR',
#  'state-province': None}

# %%
db_universities = sqlite3.connect("universities.db")

c = db_universities.cursor()

# %%
c.execute("""
CREATE TABLE IF NOT EXISTS universidades_brasil
(id INTEGER PRIMARY KEY AUTOINCREMENT,
name TEXT,
country TEXT,
state_province TEXT,
web_pages TEXT,
domains TEXT);""")

# %%
for uni in universities:
    c.execute(
        """
    INSERT INTO universidades_brasil (name, country, state_province, web_pages, domains)
    VALUES (?, ?, ?, ?, ?);""",
        (
            uni.get("name"),
            uni.get("country"),
            uni.get("state-province"),
            ", ".join(uni.get("web_pages", [])),
            ", ".join(uni.get("domains", [])),
        ),
    )

# %%
db_universities.commit()
db_universities.close()

# %%
conn = sqlite3.connect("universities.db")

# %%
def sq(str, conn=conn):
    return pd.read_sql("""{}""".format(str), conn)

# %%
sq("""SELECT * FROM sqlite_master WHERE type='table' """)
# Out:
#     type                  name              tbl_name  rootpage  \
# 0  table  universidades_brasil  universidades_brasil         2
# 1  table       sqlite_sequence       sqlite_sequence         3
#
#                                                  sql
# 0  CREATE TABLE universidades_brasil\n(id INTEGER...
# 1             CREATE TABLE sqlite_sequence(name,seq)

# %%
sq("""SELECT * FROM universidades_brasil""")
# Out:
#       id                                               name country  \
# 0      1  Universidade Comunitária da Região de Chapecó ...  Brazil
# 1      2          Centro Universitário de Brasília, UNICEUB  Brazil
# 2      3                 Centro Universitário Barao de Maua  Brazil
# 3      4                            Universidade Braz Cubas  Brazil
# 4      5                        Universidade Candido Mendes  Brazil
# ..   ...                                                ...     ...
# 375  376      Centro Universitário Álvares Penteado - FECAP  Brazil
# 376  377            Centro Universitário Facens - UniFACENS  Brazil
# 377  378  Centro Universitário Antônio Eufrásio de Toled...  Brazil
# 378  379                        Faculdade Impacta - IMPACTA  Brazil
# 379  380       Instituto de Tecnologia e Liderança - Inteli  Brazil
#
#           state_province                       web_pages  \
# 0                    NaN       https://unochapeco.edu.br
# 1                    NaN          https://www.uniceub.br
# 2                    NaN      http://www.baraodemaua.br/
# 3                    NaN        http://www.brazcubas.br/
# 4                    NaN    http://www.candidomendes.br/
# ..                   ...                             ...
# 375            São Paulo           https://www.fecap.br/
# 376            São Paulo              https://facens.br/
# 377  Presidente Prudente  https://toledoprudente.edu.br/
# 378            São Paulo     https://www.impacta.edu.br/
# 379            São Paulo      https://www.inteli.edu.br/
#
#                         domains
# 0             unochapeco.edu.br
# 1    sempreceub.com, uniceub.br
# 2                baraodemaua.br
# 3                  brazcubas.br
# 4              candidomendes.br
# ..                          ...
# 375                    fecap.br
# 376                   facens.br
# 377       toledoprudente.edu.br
# 378              impacta.edu.br
# 379               inteli.edu.br
#
# [380 rows x 6 columns]

# %%
sq("""SELECT * FROM universidades_brasil WHERE name LIKE '%Pernambuco%' """)
# Out:
#     id                                      name country state_province  \
# 0   84        Universidade Federal de Pernambuco  Brazil           None
# 1   91  Universidade Federal Rural de Pernambuco  Brazil           None
# 2  115       Universidade Católica de Pernambuco  Brazil           None
# 3  157                Universidade de Pernambuco  Brazil           None
# 4  176      Polytechnic University of Pernambuco  Brazil           None
# 5  274        Universidade Federal de Pernambuco  Brazil           None
# 6  281  Universidade Federal Rural de Pernambuco  Brazil           None
# 7  305       Universidade Católica de Pernambuco  Brazil           None
# 8  347                Universidade de Pernambuco  Brazil           None
# 9  366      Polytechnic University of Pernambuco  Brazil           None
#
#                web_pages                              domains
# 0    http://www.ufpe.br/                              ufpe.br
# 1   http://www.ufrpe.br/                             ufrpe.br
# 2  http://www.unicap.br/                            unicap.br
# 3     http://www.upe.br/                               upe.br
# 4    https://upe.poli.br  upe.poli.br, ecomp.poli.br, poli.br
# 5    http://www.ufpe.br/                              ufpe.br
# 6   http://www.ufrpe.br/                             ufrpe.br
# 7  http://www.unicap.br/                            unicap.br
# 8     http://www.upe.br/                               upe.br
# 9    https://upe.poli.br  upe.poli.br, ecomp.poli.br, poli.br

# %%
def universidades_pais(pais: str):

    pais_url = pais.title().replace(" ", "+")
    nome_tabela = pais.lower().replace(" ", "_")

    url = f"http://universities.hipolabs.com/search?country={pais_url}"

    # Teste de erros
    max_tentativas = 3
    universities = None

    for tentativa in range(max_tentativas):
        try:
            print(f"Baixando dados... (Tentativa {tentativa + 1}/{max_tentativas})")
            response = requests.get(url, timeout=15)
            response.raise_for_status()
            universities = response.json()
            break

        except (
            requests.exceptions.ChunkedEncodingError,
            requests.exceptions.ConnectionError,
        ) as e:
            print(
                "O servidor cortou a conexão no meio do caminho. Tentando novamente em 2 segundos..."
            )
            time.sleep(2)

    if not universities:
        print(
            "Erro: Não foi possível baixar os dados após várias tentativas. A API pode estar fora do ar."
        )
        return

    conn = sqlite3.connect("universities.db")
    c = conn.cursor()

    c.execute(f"""
        CREATE TABLE IF NOT EXISTS universidades_{nome_tabela}
        (id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT,
        country TEXT,
        state_province TEXT,
        web_pages TEXT,
        domains TEXT);""")

    for uni in universities:
        c.execute(
            f"""
        INSERT INTO universidades_{nome_tabela} (name, country, state_province, web_pages, domains)
        VALUES (?, ?, ?, ?, ?);""",
            (
                uni.get("name"),
                uni.get("country"),
                uni.get("state-province"),
                ", ".join(uni.get("web_pages", [])),
                ", ".join(uni.get("domains", [])),
            ),
        )

    conn.commit()
    conn.close()
    print(
        f"Sucesso! {len(universities)} universidades de {pais.title()} foram salvas na tabela universidades_{nome_tabela}."
    )

# %%
universidades_pais("ireland")
# Out:
# Baixando dados... (Tentativa 1/3)
# Sucesso! 27 universidades de Ireland foram salvas na tabela universidades_ireland.

# %% [markdown]
# ### Modularizando Extração e Carregamento de Dados

# %%
from src.extract import Extract

extract = Extract()
uni_china = extract.extract_country("china")
print(type(uni_china))
print(uni_china)
# Out:
# <class 'list'>
# [{'name': 'Sun Yat-Sen University', 'web_pages': ['https://sysu.edu.cn'], 'domains': ['mail2.sysu.edu.cn', 'mail.sysu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Hunan University', 'web_pages': ['https://www.hnu.edu.cn', 'http://www-en.hnu.edu.cn'], 'domains': ['hnu.edu.cn', 'www-en.hnu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Anhui Medical University', 'web_pages': ['http://www.ahmu.edu.cn/'], 'domains': ['ahmu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Anhui Normal University', 'web_pages': ['http://www.ahnu.edu.cn/'], 'domains': ['ahnu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Anhui Technical College of Water Resources and Hydroelectric Power', 'web_pages': ['http://www.ahsdxy.ah.edu.cn/'], 'domains': ['ahsdxy.ah.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Anhui University of Traditional Chinese Medicine', 'web_pages': ['http://www.ahtcm.edu.cn/'], 'domains': ['ahtcm.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Anhui University', 'web_pages': ['http://www.ahu.edu.cn/'], 'domains': ['ahu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Anhui University of Finance and Economics', 'web_pages': ['http://www.aufe.edu.cn/'], 'domains': ['aufe.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing University of Agriculture', 'web_pages': ['http://www.bac.edu.cn/'], 'domains': ['bac.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Foreign Studies University', 'web_pages': ['http://www.bfsu.edu.cn/'], 'domains': ['bfsu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Bohai University', 'web_pages': ['http://www.bhu.edu.cn/'], 'domains': ['bhu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing International Studies University', 'web_pages': ['http://www.bisu.edu.cn/'], 'domains': ['bisu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Institute of Technology', 'web_pages': ['http://www.bit.edu.cn/'], 'domains': ['bit.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Information Science and Technology University', 'web_pages': ['http://www.biti.edu.cn/'], 'domains': ['biti.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Jiaotong University', 'web_pages': ['https://www.bjtu.edu.cn'], 'domains': ['bjtu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': 'Beijing'}, {'name': 'China Agriculture University East', 'web_pages': ['http://www.bjaeu.edu.cn/'], 'domains': ['bjaeu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Forestry University', 'web_pages': ['http://www.bjfu.edu.cn/'], 'domains': ['bjfu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Medical University', 'web_pages': ['http://www.bjmu.edu.cn/'], 'domains': ['bjmu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Petroleum University', 'web_pages': ['http://www.bjpeu.edu.cn/'], 'domains': ['bjpeu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Polytechnic University', 'web_pages': ['http://www.bjpu.edu.cn/'], 'domains': ['bjpu.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing University of Chinese Medicine and Pharmacology', 'web_pages': ['http://www.bjucmp.edu.cn/'], 'domains': ['bjucmp.edu.cn'], 'country': 'China', 'alpha_two_code': 'CN', 'state-province': None}, {'name': 'Beijing Language and C ...

# %%
from src.load import Load

load = Load()
load.create_sqlite_table(uni_china, "universities.db", "universidades_china")
